# %% [markdown]
# # https://seaborn.pydata.org/examples/index.html

# %% [markdown]
# # line plot with multifacets

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

nuqta= sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %% [markdown]
# # relplot

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

kashti= sns.load_dataset("titanic")

sns.set_theme(style="ticks") # you can also comment out this line (used for canvas)
#defining a color pelette

p = sns.color_palette('rocket_r')

#plot lineplot (relayplot)

sns.relplot(data=nuqta,
          x="time", y="firing_rate",
          hue="coherence", size="choice", col="align",
          kind="line", size_order=["T1", "T2"], palette=p,
          height=5, aspect=.75, facet_kws=dict(sharex=False),
          )

# %% [markdown]
# # boxplot with diff palette color

# %%
import seaborn as sns
sns.set_theme(style="ticks", palette="pastel")

#load the example of tips dataset
tips= sns.load_dataset("tips")

#Draw a nested boxplot to show bills by day and time
sns.boxplot(x="day", y="total_bill",
           hue="smoker", palette=["m", "g"],
           data=tips)
sns.despine(offset=10, trim=True)

# %% [markdown]
# # violin plots

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

#load the example tips dataset
tips= sns.load_dataset("tips")

#Draw a nested violinplot and split the violins for easier comparisons
sns.violinplot(data=tips, x="day", y="total_bill", hue="smoker",
              split=True, inner="quart", linewidth=1,
              palette={"Yes":"b", "No":".85"})
sns.despine(left=True)

# %% [markdown]
# # our own plot

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

nuqta= sns.load_dataset("dots")
nuqta.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

Heera= sns.load_dataset("diamonds")
Heera.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import seaborn as sns
sns.set_theme(style="whitegrid")

nuqta = sns.load_dataset("dots")
# clarity_ranking = ["I1", "SI2", "SI1", "VS2", "VS1", "VVS2", "VVS1", "IF"]

sns.boxenplot(x="choice", y="coherence",
              color="b",
              scale="linear", data=nuqta)
# Out:
# <AxesSubplot:xlabel='choice', ylabel='coherence'>
